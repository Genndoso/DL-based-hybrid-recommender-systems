# %%
import numpy as np
import pandas as pd
from IPython.core.display import display, HTML, clear_output
display(HTML('<style>.container { width:80% !important; }</style>'))
display(HTML('<style>.prompt { min-width:10ex !important; }</style>'))
display(HTML('<style>div#notebook { font-size:12px !important; }</style>'))

from preprocessing import leave_last_out, transform_indices, preprocessing,\
reindex_data, generate_interactions_matrix, get_interaction_matrix
from datetime import datetime
from scipy.sparse import csr_matrix,diags
from scipy.sparse.linalg import svds
from evaluation import topn_recommendations
# Out:
# C:\Users\Максимилиан\AppData\Local\Temp\ipykernel_12500\2897074148.py:3: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# C:\Users\Максимилиан\AppData\Local\Temp\ipykernel_12500\2897074148.py:3: DeprecationWarning: Importing clear_output from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, clear_output
# <style>.container { width:80% !important; }</style>
# <style>.prompt { min-width:10ex !important; }</style>
# <style>div#notebook { font-size:12px !important; }</style>

# %%
from src.baselines.SVD.SVD import SVD_baseline

# %%
topn = 20

# %%
user_df = pd.read_csv('./dataset/users_processed.csv')
item_df = pd.read_csv('./dataset/items_processed.csv')
interaction_df = pd.read_csv('./dataset/interactions_processed.csv', parse_dates=['last_watch_dt'])
#submission = pd.read_csv('sample_submission.csv')

# %%
def build_ssvd_model(config, data, data_description):
    source_matrix = generate_interactions_matrix(data, data_description, rebase_users = False)
    scaled_matrix, scaling_weights = rescale_matrix(source_matrix, config['scaling'])
    
    _, s, vt = svds(scaled_matrix, k=config['rank'], return_singular_vectors='vh')
    singular_values = s[::-1]
    item_factors = np.ascontiguousarray(vt[::-1, :].T)
    return item_factors, scaling_weights 

def rescale_matrix(matrix, scaling_factor):
    frequencies = matrix.getnnz(axis=0)
    scaling_weights = np.power(frequencies, 0.5*(scaling_factor-1))
    return matrix.dot(diags(scaling_weights)),scaling_weights

def ssvd_model_scoring(params, data, data_description):
    item_factors, scaling_weights = params
    
    test_matrix = generate_interactions_matrix(data, data_description, rebase_users = True)
    #scaling_weights = np.power(frequencies, 0.5*(scaling_factor-1))
    scores = test_matrix.dot(item_factors) @ item_factors.T
    downvote_seen_items(scores, data, data_description)
    return scores

# %%
def ohe(features : list, df, items = False):
    if items:
        ohe_df = df.item_id
    else:
        ohe_df = df.user_id
    for feat in features:
        ohe_feat_df = pd.get_dummies(df[feat], prefix = feat)
        ohe_df = pd.concat([ohe_df,ohe_feat_df],axis=1)
    return ohe_df

# %%
# One-hot encoding of cathegorical features
user_cat_features = ['age','income','sex','kids_flg']

user_ohe_df  =  ohe(user_cat_features,user_df) #.drop(columns='user_id')

item_cat_feats = ['content_type','release_year_cat','for_kids','age_rating','studios','countries','directors']
item_ohe_df = ohe(item_cat_feats,item_df, items = True) #.drop(columns='item_id')

# %%
train_val, data_description, train_matrix, train_matrix_indices, cold_users_matrix, cold_start_matrix_indices = \
preprocessing(interaction_df,user_ohe_df,item_ohe_df)
# Out:
# C:\Users\Максимилиан\Desktop\Skoltech\Intro to RecSys\FP\preprocessing.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interactions_df['last_watch_dt_ts'] = interactions_df['last_watch_dt'].apply(lambda x: int(x.timestamp()))
# C:\Users\Максимилиан\Desktop\Skoltech\Intro to RecSys\FP\preprocessing.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['uid'] = data[userid].astype('category')
# C:\Users\Максимилиан\Desktop\Skoltech\Intro to RecSys\FP\preprocessing.py:209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['uid'] = data['uid'].cat.codes
# C:\Users\Максимилиан\Desktop\Skoltech\Intro to RecSys\FP\preprocessing.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['iid'] = data[itemid].astype('category')
# C:\Users\Максимилиан\Desktop\Skoltech\Intro to RecSys\FP\preprocessing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['iid'] = data['iid'].cat.codes

# %%
ranks = [b*2**n for n in range(3,9) for b in [2,3]]
scalings = [0.2,0.4,0.6,0.8]

# %%
config = {'rank': 90,
         'scaling': 0.8}

# %%
SVD_ex = SVD_baseline(train_matrix,data_description, config)

# %%
holdout = data_description['holdout_standard'][data_description['holdout_standard'].user_id.isin(train_val.user_id)]

# %% [markdown]
# # Standard scenario

# %%
# grid search
configs = {}
for rank in ranks:
    for scaling in scalings:
        iter_config = {'rank':rank,
                      'scaling': scaling}
        SVD_ex = SVD_baseline(train_matrix,data_description, iter_config)
        hr, mrr, cov, ndcg = SVD_ex.svd_evaluate(holdout = holdout)
        
        config[(rank,scaling)] = {'hr':hr,
                                 'mrr':mrr,
                                 'cov':cov,
                                 'ndcg':ndcg}
# Out:
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000
# 0
# 1000
# 2000
# 4000
# 6000
# 7000
# 10000

# %%
config_hr = {}
config_mrr = {}
config_cov = {}
config_ndcg = {}

# %%
for i in config.items():
    try:
#         config_f[i[0]] = {'hr':i[1]['hr'].mean(),
#                       'mrr':i[1]['mrr'].mean(),
#                       'cov':i[1]['cov'].mean(),
#                       'ndcg':i[1]['ndcg'].mean()
                     
#                      }
        config_mrr[i[0]] = i[1]['mrr'].mean()
        config_hr[i[0]] = i[1]['hr'].mean()
        config_cov[i[0]] = i[1]['cov'].mean()
        config_ndcg[i[0]] = i[1]['ndcg'].mean()
    except:
        pass

# %%
best_config = dict(
zip(['rank','scaling'],
   pd.Series(config_mrr).idxmax())
)

# %%
(
pd.Series(config_cov)
.unstack(level=1)
.style
.format('{:.4f}')
.background_gradient(high=0.2, axis = None)

)
# Out:
# <style type="text/css">
# #T_33245_row0_col0, #T_33245_row0_col1, #T_33245_row1_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_33245_row0_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_33245_row0_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_33245_row1_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_33245_row1_col1, #T_33245_row3_col2, #T_33245_row4_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_33245_row1_col2, #T_33245_row2_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_33245_row2_col0, #T_33245_row6_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_33245_row2_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_33245_row2_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_33245_row3_col0 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_33245_row3_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_33245_row3_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_33245_row4_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_33245_row4_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_33245_row4_col2 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_33245_row5_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_33245_row5_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_33245_row5_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_33245_row5_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_33245_row6_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_33245_row6_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_33245_row6_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_33245_row7_col0 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_33245_row7_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_33245_row7_col2 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_33245_row7_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_33245_row8_col0 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_33245_row8_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_33245_row8_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_33245_row8_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_33245_row9_col0 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_33245_row9_col1 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_33245_row9_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_33245_row9_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_33245_row10_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_33245_row10_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_33245_row10_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_33245_row10_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_33245_row11_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_33245_row11_col1 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_33245_row11_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_33245_row11_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# </style>
# <table id="T_33245_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.2</th>
#       <th class="col_heading level0 col1" >0.4</th>
#       <th class="col_heading level0 col2" >0.6</th>
#       <th class="col_heading level0 col3" >0.8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33245_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_33245_row0_col0" class="data row0 col0" >0.0274</td>
#       <td id="T_33245_row0_col1" class="data row0 col1" >0.0303</td>
#       <td id="T_33245_row0_col2" class="data row0 col2" >0.0232</td>
#       <td id="T_33245_row0_col3" class="data row0 col3" >0.0202</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row1" class="row_heading level0 row1" >24</th>
#       <td id="T_33245_row1_col0" class="data row1 col0" >0.0495</td>
#       <td id="T_33245_row1_col1" class="data row1 col1" >0.0454</td>
#       <td id="T_33245_row1_col2" class="data row1 col2" >0.0308</td>
#       <td id="T_33245_row1_col3" class="data row1 col3" >0.0281</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row2" class="row_heading level0 row2" >32</th>
#       <td id="T_33245_row2_col0" class="data row2 col0" >0.0629</td>
#       <td id="T_33245_row2_col1" class="data row2 col1" >0.0584</td>
#       <td id="T_33245_row2_col2" class="data row2 col2" >0.0372</td>
#       <td id="T_33245_row2_col3" class="data row2 col3" >0.0319</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_33245_row3_col0" class="data row3 col0" >0.0942</td>
#       <td id="T_33245_row3_col1" class="data row3 col1" >0.0723</td>
#       <td id="T_33245_row3_col2" class="data row3 col2" >0.0463</td>
#       <td id="T_33245_row3_col3" class="data row3 col3" >0.0393</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row4" class="row_heading level0 row4" >64</th>
#       <td id="T_33245_row4_col0" class="data row4 col0" >0.1249</td>
#       <td id="T_33245_row4_col1" class="data row4 col1" >0.0878</td>
#       <td id="T_33245_row4_col2" class="data row4 col2" >0.0536</td>
#       <td id="T_33245_row4_col3" class="data row4 col3" >0.0454</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row5" class="row_heading level0 row5" >96</th>
#       <td id="T_33245_row5_col0" class="data row5 col0" >0.1683</td>
#       <td id="T_33245_row5_col1" class="data row5 col1" >0.1113</td>
#       <td id="T_33245_row5_col2" class="data row5 col2" >0.0685</td>
#       <td id="T_33245_row5_col3" class="data row5 col3" >0.0549</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row6" class="row_heading level0 row6" >128</th>
#       <td id="T_33245_row6_col0" class="data row6 col0" >0.2072</td>
#       <td id="T_33245_row6_col1" class="data row6 col1" >0.1316</td>
#       <td id="T_33245_row6_col2" class="data row6 col2" >0.0797</td>
#       <td id="T_33245_row6_col3" class="data row6 col3" >0.0662</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row7" class="row_heading level0 row7" >192</th>
#       <td id="T_33245_row7_col0" class="data row7 col0" >0.2677</td>
#       <td id="T_33245_row7_col1" class="data row7 col1" >0.1705</td>
#       <td id="T_33245_row7_col2" class="data row7 col2" >0.1031</td>
#       <td id="T_33245_row7_col3" class="data row7 col3" >0.0806</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row8" class="row_heading level0 row8" >256</th>
#       <td id="T_33245_row8_col0" class="data row8 col0" >0.3081</td>
#       <td id="T_33245_row8_col1" class="data row8 col1" >0.1966</td>
#       <td id="T_33245_row8_col2" class="data row8 col2" >0.1187</td>
#       <td id="T_33245_row8_col3" class="data row8 col3" >0.0952</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row9" class="row_heading level0 row9" >384</th>
#       <td id="T_33245_row9_col0" class="data row9 col0" >0.3666</td>
#       <td id="T_33245_row9_col1" class="data row9 col1" >0.2422</td>
#       <td id="T_33245_row9_col2" class="data row9 col2" >0.1500</td>
#       <td id="T_33245_row9_col3" class="data row9 col3" >0.1207</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row10" class="row_heading level0 row10" >512</th>
#       <td id="T_33245_row10_col0" class="data row10 col0" >0.4068</td>
#       <td id="T_33245_row10_col1" class="data row10 col1" >0.2705</td>
#       <td id="T_33245_row10_col2" class="data row10 col2" >0.1767</td>
#       <td id="T_33245_row10_col3" class="data row10 col3" >0.1410</td>
#     </tr>
#     <tr>
#       <th id="T_33245_level0_row11" class="row_heading level0 row11" >768</th>
#       <td id="T_33245_row11_col0" class="data row11 col0" >0.4493</td>
#       <td id="T_33245_row11_col1" class="data row11 col1" >0.3227</td>
#       <td id="T_33245_row11_col2" class="data row11 col2" >0.2165</td>
#       <td id="T_33245_row11_col3" class="data row11 col3" >0.1742</td>
#     </tr>
#   </tbody>
# </table>

# %%
(
pd.Series(config_mrr)
.unstack(level=1)
.style
.format('{:.4f}')
.background_gradient(high=0.2, axis = None)

)
# Out:
# <style type="text/css">
# #T_214e5_row0_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_214e5_row0_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_214e5_row0_col2 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_214e5_row0_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_214e5_row1_col0 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_214e5_row1_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_214e5_row1_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_214e5_row1_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_214e5_row2_col0 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_214e5_row2_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_214e5_row2_col2 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_214e5_row2_col3 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_214e5_row3_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_214e5_row3_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_214e5_row3_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_214e5_row3_col3 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_214e5_row4_col0 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_214e5_row4_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_214e5_row4_col2, #T_214e5_row5_col1, #T_214e5_row10_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_214e5_row4_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_214e5_row5_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_214e5_row5_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_214e5_row5_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_214e5_row6_col0 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_214e5_row6_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_214e5_row6_col2, #T_214e5_row6_col3, #T_214e5_row7_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_214e5_row7_col0 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_214e5_row7_col2, #T_214e5_row8_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_214e5_row7_col3, #T_214e5_row11_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_214e5_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_214e5_row8_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_214e5_row8_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_214e5_row9_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_214e5_row9_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_214e5_row9_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_214e5_row9_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_214e5_row10_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_214e5_row10_col2, #T_214e5_row10_col3, #T_214e5_row11_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_214e5_row11_col2, #T_214e5_row11_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_214e5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.2</th>
#       <th class="col_heading level0 col1" >0.4</th>
#       <th class="col_heading level0 col2" >0.6</th>
#       <th class="col_heading level0 col3" >0.8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_214e5_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_214e5_row0_col0" class="data row0 col0" >0.0635</td>
#       <td id="T_214e5_row0_col1" class="data row0 col1" >0.0480</td>
#       <td id="T_214e5_row0_col2" class="data row0 col2" >0.0350</td>
#       <td id="T_214e5_row0_col3" class="data row0 col3" >0.0336</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row1" class="row_heading level0 row1" >24</th>
#       <td id="T_214e5_row1_col0" class="data row1 col0" >0.0565</td>
#       <td id="T_214e5_row1_col1" class="data row1 col1" >0.0415</td>
#       <td id="T_214e5_row1_col2" class="data row1 col2" >0.0297</td>
#       <td id="T_214e5_row1_col3" class="data row1 col3" >0.0281</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row2" class="row_heading level0 row2" >32</th>
#       <td id="T_214e5_row2_col0" class="data row2 col0" >0.0533</td>
#       <td id="T_214e5_row2_col1" class="data row2 col1" >0.0384</td>
#       <td id="T_214e5_row2_col2" class="data row2 col2" >0.0277</td>
#       <td id="T_214e5_row2_col3" class="data row2 col3" >0.0268</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_214e5_row3_col0" class="data row3 col0" >0.0495</td>
#       <td id="T_214e5_row3_col1" class="data row3 col1" >0.0313</td>
#       <td id="T_214e5_row3_col2" class="data row3 col2" >0.0249</td>
#       <td id="T_214e5_row3_col3" class="data row3 col3" >0.0238</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row4" class="row_heading level0 row4" >64</th>
#       <td id="T_214e5_row4_col0" class="data row4 col0" >0.0457</td>
#       <td id="T_214e5_row4_col1" class="data row4 col1" >0.0270</td>
#       <td id="T_214e5_row4_col2" class="data row4 col2" >0.0225</td>
#       <td id="T_214e5_row4_col3" class="data row4 col3" >0.0217</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row5" class="row_heading level0 row5" >96</th>
#       <td id="T_214e5_row5_col0" class="data row5 col0" >0.0435</td>
#       <td id="T_214e5_row5_col1" class="data row5 col1" >0.0227</td>
#       <td id="T_214e5_row5_col2" class="data row5 col2" >0.0203</td>
#       <td id="T_214e5_row5_col3" class="data row5 col3" >0.0199</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row6" class="row_heading level0 row6" >128</th>
#       <td id="T_214e5_row6_col0" class="data row6 col0" >0.0413</td>
#       <td id="T_214e5_row6_col1" class="data row6 col1" >0.0214</td>
#       <td id="T_214e5_row6_col2" class="data row6 col2" >0.0190</td>
#       <td id="T_214e5_row6_col3" class="data row6 col3" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row7" class="row_heading level0 row7" >192</th>
#       <td id="T_214e5_row7_col0" class="data row7 col0" >0.0340</td>
#       <td id="T_214e5_row7_col1" class="data row7 col1" >0.0190</td>
#       <td id="T_214e5_row7_col2" class="data row7 col2" >0.0178</td>
#       <td id="T_214e5_row7_col3" class="data row7 col3" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row8" class="row_heading level0 row8" >256</th>
#       <td id="T_214e5_row8_col0" class="data row8 col0" >0.0304</td>
#       <td id="T_214e5_row8_col1" class="data row8 col1" >0.0178</td>
#       <td id="T_214e5_row8_col2" class="data row8 col2" >0.0163</td>
#       <td id="T_214e5_row8_col3" class="data row8 col3" >0.0169</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row9" class="row_heading level0 row9" >384</th>
#       <td id="T_214e5_row9_col0" class="data row9 col0" >0.0262</td>
#       <td id="T_214e5_row9_col1" class="data row9 col1" >0.0164</td>
#       <td id="T_214e5_row9_col2" class="data row9 col2" >0.0152</td>
#       <td id="T_214e5_row9_col3" class="data row9 col3" >0.0151</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row10" class="row_heading level0 row10" >512</th>
#       <td id="T_214e5_row10_col0" class="data row10 col0" >0.0225</td>
#       <td id="T_214e5_row10_col1" class="data row10 col1" >0.0154</td>
#       <td id="T_214e5_row10_col2" class="data row10 col2" >0.0148</td>
#       <td id="T_214e5_row10_col3" class="data row10 col3" >0.0148</td>
#     </tr>
#     <tr>
#       <th id="T_214e5_level0_row11" class="row_heading level0 row11" >768</th>
#       <td id="T_214e5_row11_col0" class="data row11 col0" >0.0180</td>
#       <td id="T_214e5_row11_col1" class="data row11 col1" >0.0147</td>
#       <td id="T_214e5_row11_col2" class="data row11 col2" >0.0138</td>
#       <td id="T_214e5_row11_col3" class="data row11 col3" >0.0138</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('HR mean:',hr.mean())
print('MRR mean:',mrr.mean())
print('Coverage mean:',cov.mean())
print('NDCG mean:',ndcg.mean())
# Out:
# HR mean: 0.05479207567374621
# MRR mean: 0.02005130235521103
# Coverage mean: 0.0545479247333741
# NDCG mean: 2.7914775049185005e-06

# %% [markdown]
# # Coldstart

# %%
holdout_cs = data_description['holdout_cs']

# %%
holdout_cs = holdout_cs[holdout_cs.user_id.isin(cold_start_matrix_indices['uid_to_user_id'].values())]

# %%
#user_factors, item_factors = SVD_ex.build_svd_model()

# %%
def user_evaluate(user_id, preds, holdout,data_description):
        n_items = data_description['n_items']
        holdout_user = holdout[holdout.user_id == user_id]
        predictions = preds[user_id]
        hits_mask = predictions == holdout_user.item_id.values
        # HR calculation
        hr = np.mean(hits_mask.any(axis=0))
        # MRR calculation
        n_test_users = preds.shape[0]
        hit_rank = np.where(hits_mask)[0] + 1.0

        mrr = np.sum(1 / hit_rank)
        # coverage calculation
        cov = np.unique(preds).size / n_items
        # ndcg
        # NDCG
        ndcg_per_user = 1.0 / np.log2(hit_rank + 1)
        ndcg = np.sum(ndcg_per_user) / n_test_users

        return hr, mrr, cov, ndcg

# %%
# grid search
config_hr = {}
config_mrr = {}
config_cov = {}
config_ndcg = {}

hr_full = []
mrr_full = []
cov_full = []
ndcg_full = []
for rank in ranks:
    for scaling in scalings:
        iter_config = {'rank':rank,
                      'scaling': scaling}
        SVD_ex = SVD_baseline(train_matrix,data_description, iter_config)
        user_factors, item_factors = SVD_ex.build_svd_model()
        cs_scores = cold_users_matrix[:20000,:].dot(item_factors) @ item_factors.T
        scores_topn = topn_recommendations(cs_scores[:20000,:],topn)
        
        for n,i in enumerate(holdout_cs.user_id.sort_values()):
            if n == 9000:
                break
            hr, mrr, cov, ndcg = user_evaluate(i,scores_topn, holdout_cs,data_description)
            hr_full.append(hr)
            mrr_full.append(mrr)
            cov_full.append(cov)
            ndcg_full.append(ndcg)
        
        config_ndcg[(rank,scaling)] = np.array(ndcg_full).mean()
        config_hr[(rank,scaling)] = np.array(hr).mean()
        config_mrr[(rank,scaling)] = np.array(mrr).mean()
        config_cov[(rank,scaling)] = np.array(cov).mean()
        
        print(config_mrr[(rank,scaling)],config_cov[(rank,scaling)])
#         config[(rank,scaling)] = {'hr':hr.mean(),
#                                  'mrr':mrr.mean(),
#                                  'cov':cov.mean(),
#                                  'ndcg':ndcg.mean()}
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 23
#      21 if n == 9000:
#      22     break
# ---> 23 hr, mrr, cov, ndcg = user_evaluate(i,scores_topn, holdout_cs,data_description)
#      24 hr_full.append(hr)
#      25 mrr_full.append(mrr)
#
# Cell In[16], line 4, in user_evaluate(user_id, preds, holdout, data_description)
#       2 n_items = data_description['n_items']
#       3 holdout_user = holdout[holdout.user_id == user_id]
# ----> 4 predictions = preds[user_id]
#       5 hits_mask = predictions == holdout_user.item_id.values
#       6 # HR calculation
#
# IndexError: index 20002 is out of bounds for axis 0 with size 20000

# %%
scores_topn = topn_recommendations(cs_scores[:20000,:],topn)

# %%
hr, mrr, cov, ndcg = user_evaluate(10,scores_topn, holdout_cs,data_description)

# %%
(
pd.Series(config_mrr)
.unstack(level=1)
.style
.format('{:.4f}')
.background_gradient(high=0.2, axis = None)

)
# Out:
# <style type="text/css">
# #T_49a05_row0_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_49a05_row0_col1, #T_49a05_row1_col1, #T_49a05_row4_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_49a05_row0_col2, #T_49a05_row0_col3, #T_49a05_row1_col2, #T_49a05_row1_col3, #T_49a05_row3_col1, #T_49a05_row5_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_49a05_row1_col0, #T_49a05_row2_col0, #T_49a05_row2_col1, #T_49a05_row3_col0, #T_49a05_row4_col0, #T_49a05_row4_col3, #T_49a05_row5_col0, #T_49a05_row5_col2, #T_49a05_row5_col3, #T_49a05_row6_col0, #T_49a05_row6_col2, #T_49a05_row6_col3, #T_49a05_row7_col0, #T_49a05_row7_col1, #T_49a05_row7_col2, #T_49a05_row7_col3, #T_49a05_row8_col0, #T_49a05_row8_col1, #T_49a05_row8_col2, #T_49a05_row8_col3, #T_49a05_row9_col0, #T_49a05_row9_col1, #T_49a05_row9_col2, #T_49a05_row9_col3, #T_49a05_row10_col0, #T_49a05_row10_col1, #T_49a05_row10_col2, #T_49a05_row10_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_49a05_row2_col2, #T_49a05_row3_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_49a05_row2_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_49a05_row3_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_49a05_row4_col2, #T_49a05_row6_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# </style>
# <table id="T_49a05_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.2</th>
#       <th class="col_heading level0 col1" >0.4</th>
#       <th class="col_heading level0 col2" >0.6</th>
#       <th class="col_heading level0 col3" >0.8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49a05_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_49a05_row0_col0" class="data row0 col0" >0.0667</td>
#       <td id="T_49a05_row0_col1" class="data row0 col1" >0.2500</td>
#       <td id="T_49a05_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_49a05_row0_col3" class="data row0 col3" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row1" class="row_heading level0 row1" >24</th>
#       <td id="T_49a05_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_49a05_row1_col1" class="data row1 col1" >0.2500</td>
#       <td id="T_49a05_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_49a05_row1_col3" class="data row1 col3" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row2" class="row_heading level0 row2" >32</th>
#       <td id="T_49a05_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_49a05_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_49a05_row2_col2" class="data row2 col2" >0.2000</td>
#       <td id="T_49a05_row2_col3" class="data row2 col3" >0.3333</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_49a05_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_49a05_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_49a05_row3_col2" class="data row3 col2" >0.2000</td>
#       <td id="T_49a05_row3_col3" class="data row3 col3" >0.1250</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row4" class="row_heading level0 row4" >64</th>
#       <td id="T_49a05_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_49a05_row4_col1" class="data row4 col1" >0.2500</td>
#       <td id="T_49a05_row4_col2" class="data row4 col2" >0.1667</td>
#       <td id="T_49a05_row4_col3" class="data row4 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row5" class="row_heading level0 row5" >96</th>
#       <td id="T_49a05_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_49a05_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_49a05_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_49a05_row5_col3" class="data row5 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row6" class="row_heading level0 row6" >128</th>
#       <td id="T_49a05_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_49a05_row6_col1" class="data row6 col1" >0.1667</td>
#       <td id="T_49a05_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_49a05_row6_col3" class="data row6 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row7" class="row_heading level0 row7" >192</th>
#       <td id="T_49a05_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_49a05_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_49a05_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_49a05_row7_col3" class="data row7 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row8" class="row_heading level0 row8" >256</th>
#       <td id="T_49a05_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_49a05_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_49a05_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_49a05_row8_col3" class="data row8 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row9" class="row_heading level0 row9" >384</th>
#       <td id="T_49a05_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_49a05_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_49a05_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_49a05_row9_col3" class="data row9 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_49a05_level0_row10" class="row_heading level0 row10" >512</th>
#       <td id="T_49a05_row10_col0" class="data row10 col0" >0.0000</td>
#       <td id="T_49a05_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_49a05_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_49a05_row10_col3" class="data row10 col3" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
hr = np.array(hr_full)
mrr = np.array(mrr_full)
cov = np.array(cov_full) 
ndcg = np.array(ndcg_full)

# %%
print('HR mean:',hr.mean())
print('MRR mean:',mrr.mean())
print('Coverage mean:',cov.mean())
print('NDCG mean:',ndcg.mean())
# Out:
# HR mean: 0.03508616095221176
# MRR mean: 0.007450015843163309
# Coverage mean: 0.043950818558521836
# NDCG mean: 6.685945875394102e-07
